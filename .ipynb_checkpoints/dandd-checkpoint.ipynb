# %%
charname = str(input("Hello adventurer! What name would you like to be called by in the legends that shall be written about your journeys? "))
print ("Well hello there ",charname, "we are glad to be here at the beginning of your tales." )
# ask for class
# give class advice using name and class
# print character output
# Out:
# Hello adventurer! What name would you like to be called by in the legends that shall be written about your journeys?  kermit
# Well hello there  kermit we are glad to be here at the beginning of your tales.

# %%
print("Tell me, " + charname + ", what type of adventurer are you? Please enter a number coordinating to your answer!")
print("0.Barbarian 1.Bard 2.Cleric 3.Druid 4.Fighter 5.Monk 6.Paladin 7.Ranger 8.Rogue 9.Sorcerer 10.Warlock 11.Wizard")

array = ["Barbarian", "Bard", "Cleric", "Druid", "Fighter", "Monk", "Paladin", "Ranger", "Rogue", "Sorcerer", "Warlock", "Wizard",]

dnd_class = array[int(input())]
print("Ah, so you have chosen to be a " + dnd_class + "! Interesting choice... I wonder what you will acheive on this path you have chosen, " + charname + " the " + dnd_class + "!")
# Out:
# Tell me, kermit, what type of adventurer are you? Please enter a number coordinating to your answer!
# 0.Barbarian 1.Bard 2.Cleric 3.Druid 4.Fighter 5.Monk 6.Paladin 7.Ranger 8.Rogue 9.Sorcerer 10.Warlock 11.Wizard
#  10
# Ah, so you have chosen to be a Warlock! Interesting choice... I wonder what you will acheive on this path you have chosen, kermit the Warlock!
